# %%
45*7/2
# Out:
# 157.5

# %%
'junaid' + 'ahmad'
# Out:
# 'junaidahmad'

# %%
"ha" *99
# Out:
# 'hahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahahaha'

# %%
123
# Out:
# 123

# %%
1+1
# Out:
# 2

# %% [markdown]
# # Heading 1

# %% [markdown]
# ## Heading 2

# %% [markdown]
# ### Heading 3

# %% [markdown]
# #### Heading 4

# %% [markdown]
# __THIS IS BOLD TEXT__

# %% [markdown]
# *THIS IS ITALIC* _THIS IS ITALIC_

# %% [markdown]
# $+$ THIS IS MATHEMATICAL SYMBOL

# %% [markdown]
# - this is bullet point

# %% [markdown]
# * MAIN
#     * SUB

# %% [markdown]
# __[GOOGLE](https://www.google.com)__

# %% [markdown]
# <img src="https://images.pexels.com/photos/669612/pexels-photo-669612.jpeg?auto=compress&cs=tinysrgb&dpr=2&h=650&w=940"/>

# %% [markdown]
# ### IMP NOTE
# - Each cell's output gives the value evaluated by last expression of that cell

# %%
37 + 64
1 + 1
# Out:
# 2

# %%
color = 'PURPLE'
color * 2
# Out:
# 'PURPLEPURPLE'

# %%
color
# Out:
# 'PURPLE'

# %%
import statistics

# %%
color
